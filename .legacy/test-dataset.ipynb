# %%
import numpy as np
import pandas as pd

# %%
# Data loading

dataset = pd.read_csv('Run200_Wave_0_1.txt', sep=' ', header=None, skipinitialspace=True)
# dataset = dataset.drop([0, 1, 2, 3, 504], axis=1)
dataset.columns = list(range(500))
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 dataset = pd.read_csv('Run200_Wave_0_1.txt', sep=' ', header=None, skipinitialspace=True)
#       4 # dataset = dataset.drop([0, 1, 2, 3, 504], axis=1)
# ----> 5 dataset.columns = list(range(500))
#       6 dataset.head()
#
# File c:\Users\NVME_1TB\Desktop\projects\ML_2024\ML_2024_venv\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\NVME_1TB\Desktop\projects\ML_2024\ML_2024_venv\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
# ...

# %%
dataset.shape
# Out:
# (23479, 500)

# %%
N=range(0,10000)
ax = dataset.T[N][140:200].plot(title='Signal' ,legend=None,figsize=(20,10))
ax.set_xlabel("time, ns")
ax.set_ylabel("bit ADC")
# Out:
# Text(0, 0.5, 'bit ADC')

# %%
ax = (2**14-dataset.T[N]-1560)[145:170].plot(title='Signal' ,legend=None,figsize=(20,10))
ax.set_xlabel("time, ns")
ax.set_ylabel("bit ADC")
# Out:
# Text(0, 0.5, 'bit ADC')
